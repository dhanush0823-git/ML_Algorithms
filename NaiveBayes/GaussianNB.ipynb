# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import seaborn as sns

# %%
df = pd.read_csv('gaussian_NB.csv')

# %%
df.head()
# Out:
#    age  study_hours_per_day  attendance_percent  assignment_score  exam_score  \
# 0   26                 5.87               90.31             76.21       91.77
# 1   33                 4.43               96.02             84.09       99.20
# 2   29                 5.62               89.25             76.27       85.36
# 3   31                 2.96               66.38             46.02       71.46
# 4   29                 6.46               82.50             82.43       81.88
#
#    sleep_hours  screen_time_hours  final_result
# 0         7.84               4.13             1
# 1         6.65               1.57             1
# 2         6.70               3.41             1
# 3         6.76               9.74             0
# 4         6.79               5.11             1

# %%
x = df.drop(columns='final_result')
y = df['final_result']

# %%
sns.boxplot(x)
# Out:
# <Axes: >

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
main_pipeline = Pipeline(
    steps=[
        ('scaling',MinMaxScaler()),
        ('model',GaussianNB())
    ]
)
main_pipeline.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('scaling', MinMaxScaler()), ('model', GaussianNB())])

# %%
print("--------------------Train------------------------------")
print(classification_report(ytrain,main_pipeline.predict(xtrain)))
print("--------------------Test------------------------------")
print(classification_report(ytest,main_pipeline.predict(xtest)))
# Out:
# --------------------Train------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       124
#            1       1.00      1.00      1.00       116
#
#     accuracy                           1.00       240
#    macro avg       1.00      1.00      1.00       240
# weighted avg       1.00      1.00      1.00       240
#
# --------------------Test------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        34
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60
