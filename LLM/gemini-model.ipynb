# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# Api key --> AIzaSyA4jB_a74SReYRhUUl7YD-pt4EtNtrcJPU

# %%
llm_model = ChatGoogleGenerativeAI(
    model = 'gemini-3.5-flash',
    api_key = 'AIzaSyA4jB_a74SReYRhUUl7YD-pt4EtNtrcJPU'
)

# %%
response = llm_model.invoke('What is LLM?') # sends the request and returns the response(text generation)

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': '**LLM** stands for **Large Language Model**. \n\nAt its core, an LLM is a type of artificial intelligence (AI) program trained on massive amounts of text data to understand, process, and generate human-like language. \n\nIf you have ever used ChatGPT, Google Gemini, or Claude, you have interacted with an LLM.\n\nHere is a breakdown of what LLMs are, how they work, and what they can do.\n\n---\n\n### 1. What makes them "Large"?\nThe "Large" in LLM refers to two things:\n*   **Massive Training Data:** They are trained on datasets containing billions or trillions of words sourced from books, articles, websites, and code repositories.\n*   **Huge Number of Parameters:** "Parameters" are the internal settings or "connections" the model uses to make decisions. Modern LLMs have billions (and sometimes trillions) of these parameters, which act like artificial brain cells.\n\n### 2. How Do LLMs Work?\nAt their most basic level, LLMs are **extremely
# ...

# %%
response.content[0]['text'] # This is how we can access the generated text
# Out:
# '**LLM** stands for **Large Language Model**. \n\nAt its core, an LLM is a type of artificial intelligence (AI) program trained on massive amounts of text data to understand, process, and generate human-like language. \n\nIf you have ever used ChatGPT, Google Gemini, or Claude, you have interacted with an LLM.\n\nHere is a breakdown of what LLMs are, how they work, and what they can do.\n\n---\n\n### 1. What makes them "Large"?\nThe "Large" in LLM refers to two things:\n*   **Massive Training Data:** They are trained on datasets containing billions or trillions of words sourced from books, articles, websites, and code repositories.\n*   **Huge Number of Parameters:** "Parameters" are the internal settings or "connections" the model uses to make decisions. Modern LLMs have billions (and sometimes trillions) of these parameters, which act like artificial brain cells.\n\n### 2. How Do LLMs Work?\nAt their most basic level, LLMs are **extremely advanced autocomplete engines**. \n\n1.  **
# ...
