# %%
import pandas as pd

# %%
df = pd.read_csv('DT_Classifier.csv')

# %%
df.head()
# Out:
#         age       bmi  blood_pressure  glucose_level  insulin_level  \
# 0  2.702873  2.181128       -1.514859      -0.281670       1.027056
# 1 -0.171621 -1.678788       -1.504651       1.985878       0.297711
# 2 -1.578785 -0.763132        0.538121       1.353756      -0.137251
# 3  0.646361  1.442334        0.139805      -1.988097       2.186118
# 4  1.972422 -0.834799       -3.433475       1.539675       1.386393
#
#    physical_activity  diabetes
# 0          -0.351196         1
# 1          -0.085608         1
# 2           0.353548         1
# 3          -1.729898         1
# 4           0.195845         0

# %%
df.isnull().sum()
# Out:
# age                  0
# bmi                  0
# blood_pressure       0
# glucose_level        0
# insulin_level        0
# physical_activity    0
# diabetes             0
# dtype: int64
